# %% [markdown]
# Linear Regression

# %% [markdown]
# *  Used to predict numeric values

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
# !pip install -q sklearn

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# Load Libraries

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

# %% [markdown]
# Load Data

# %%
# Load dataset.
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') #training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') #testing data

# %%
dftrain.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
y_train = dftrain.pop('survived')
y_eval = dfeval.pop('survived')
dftrain.head()
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 622    0
# 623    0
# 624    1
# 625    0
# 626    0
# Name: survived, Length: 627, dtype: int64

# %%
print(dftrain.loc[0], y_train[0])
# Out:
# sex                          male
# age                          22.0
# n_siblings_spouses              1
# parch                           0
# fare                         7.25
# class                       Third
# deck                      unknown
# embark_town           Southampton
# alone                           n
# Name: 0, dtype: object 0

# %%
print(dftrain['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      28.0
#        ...
# 622    28.0
# 623    25.0
# 624    19.0
# 625    28.0
# 626    32.0
# Name: age, Length: 627, dtype: float64

# %%
dftrain.describe()
# Out:
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200

# %%
dftrain.shape
# Out:
# (627, 9)

# %%
y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
dftrain.age.hist(bins=20)

# %%
dftrain.sex.value_counts().plot(kind = 'barh')

# %%
dftrain['class'].value_counts().plot(kind = 'barh')

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind = 'barh').set_xlabel('% survive')
# Out:
# Text(0.5, 0, '% survive')

# %% [markdown]
# Training and Testing Datasets

# %%
dfeval.shape
# Out:
# (264, 9)

# %%
CATEGORICAL_COLUMNS = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
  vocabulary = dftrain[feature_name].unique()
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
  feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  SequenceNumericColumn(key='age', shape=(1,), default_value=0.0, dtype=tf.float32, normalizer_fn=None),
#  SequenceNumericColumn(key='fare', shape=(1,), default_value=0.0, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# Input function

# %%
def make_input_fn(data_df, label_df, num_epochs=20, shuffle=True, batch_size=32):
  def input_function():
    ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
    if shuffle:
      ds = ds.shuffle(1000)
    ds = ds.batch(batch_size).repeat(num_epochs)
    return ds
  return input_function

train_input_fn = make_input_fn(dftrain, y_train)
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %% [markdown]
# Creating the Model

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp487q5bs_

# %% [markdown]
# Train the Model

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
linear_est.train(train_input_fn)
result = linear_est.evaluate(eval_input_fn)

clear_output()
print(result)
# Out:
# {'accuracy': 0.7651515, 'accuracy_baseline': 0.625, 'auc': 0.8348026, 'auc_precision_recall': 0.7918581, 'average_loss': 0.4701618, 'label/mean': 0.375, 'loss': 0.4595473, 'precision': 0.68686867, 'prediction/mean': 0.38826153, 'recall': 0.68686867, 'global_step': 400}

# %%
result = list(linear_est.predict(eval_input_fn))
result
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/canned/linear.py:1478: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   getter=tf.compat.v1.get_variable)
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07058433], dtype=float32),
#   'logits': array([-2.5777478], dtype=float32),
#   'probabilities': array([0.92941564, 0.07058433], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39630252], dtype=float32),
#   'logits': array([-0.42089546], dtype=float32),
#   'probabilities': array([0.6036975, 0.3963025], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72775525], dtype=float32),
#   'logits': array([0.9832634], dtype=float32),
#   'probabilities': array([0.27224472, 0.72775525], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62284535], dtype=float32),
#   'logits': array([0.50164294], dtype=float32),
#   'probabilities': array([0.37715465, 0.62284535], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26552895], dtype=float32),
#   'logits': array([-1.0174267], dtype=float32),
#   'probabilities': array([0.734471  , 0.26552895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76949394], dtype=float32),
#   'logits': array([1.2054559], dtype=float32),
#   'probabilities': array([0.23050606, 0.76949394], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5335929], dtype=float32),
#   'logits': array([0.13457419], dtype=float32),
#   'probabilities': array([0.46640715, 0.5335929 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10696533], dtype=float32),
#   'logits': array([-2.1221204], dtype=float32),
#   'probabilities': array([0.8930346 , 0.10696535], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63355863], dtype=float32),
#   'logits': array([0.5475141], dtype=float32),
#   'probabilities': array([0.36644134, 0.63355863], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74544996], dtype=float32),
#   'logits': array([1.0744908], dtype=float32),
#   'probabilities': array([0.25455, 0.74545], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68587637], dtype=float32),
#   'logits': array([0.78091073], dtype=float32),
#   'probabilities': array([0.31412363, 0.68587637], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10684028], dtype=float32),
#   'logits': array([-2.12343], dtype=float32),
#   'probabilities': array([0.89315975, 0.10684033], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.87689185], dtype=float32),
#   'logits': array([1.9633204], dtype=float32),
#   'probabilities': array([0.12310816, 0.87689185], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41210413], dtype=float32),
#   'logits': array([-0.35527378], dtype=float32),
#   'probabilities': array([0.5878958 , 0.41210413], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8612322], dtype=float32),
#   'logits': array([1.825562], dtype=float32),
#   'probabilities': array([0.13876781, 0.86123216], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5333365], dtype=float32),
#   'logits': array([0.13354422], dtype=float32),
#   'probabilities': array([0.46666348, 0.5333365 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15212578], dtype=float32),
#   'logits': array([-1.7180247], dtype=float32),
#   'probabilities': array([0.8478742 , 0.15212576], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84677553], dtype=float32),
#   'logits': array([1.7095318], dtype=float32),
#   'probabilities': array([0.15322445, 0.84677553], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29497188], dtype=float32),
#   'logits': array([-0.8713577], dtype=float32),
#   'probabilities': array([0.7050281 , 0.29497185], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08451852], dtype=float32),
#   'logits': array([-2.3824787], dtype=float32),
#   'probabilities': array([0.91548145, 0.08451858], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11001366], dtype=float32),
#   'logits': array([-2.0906014], dtype=float32),
#   'probabilities': array([0.88998634, 0.11001368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07970604], dtype=float32),
#   'logits': array([-2.4463475], dtype=float32),
#   'probabilities': array([0.9202939 , 0.07970607], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68413895], dtype=float32),
#   'logits': array([0.77285874], dtype=float32),
#   'probabilities': array([0.31586102, 0.68413895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06439298], dtype=float32),
#   'logits': array([-2.6761901], dtype=float32),
#   'probabilities': array([0.93560696, 0.06439303], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69340694], dtype=float32),
#   'logits': array([0.8160958], dtype=float32),
#   'probabilities': array([0.30659303, 0.693407  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5811111], dtype=float32),
#   'logits': array([0.3273362], dtype=float32),
#   'probabilities': array([0.4188889, 0.5811111], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2034497], dtype=float32),
#   'logits': array([-1.3648714], dtype=float32),
#   'probabilities': array([0.7965503 , 0.20344973], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30640334], dtype=float32),
#   'logits': array([-0.8169883], dtype=float32),
#   'probabilities': array([0.69359666, 0.30640334], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21768177], dtype=float32),
#   'logits': array([-1.2792274], dtype=float32),
#   'probabilities': array([0.7823182 , 0.21768177], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86138904], dtype=float32),
#   'logits': array([1.8268754], dtype=float32),
#   'probabilities': array([0.13861091, 0.86138904], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12137264], dtype=float32),
#   'logits': array([-1.979495], dtype=float32),
#   'probabilities': array([0.8786273 , 0.12137268], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80210376], dtype=float32),
#   'logits': array([1.399495], dtype=float32),
#   'probabilities': array([0.19789626, 0.80210376], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19235125], dtype=float32),
#   'logits': array([-1.4348042], dtype=float32),
#   'probabilities': array([0.8076487 , 0.19235124], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6720521], dtype=float32),
#   'logits': array([0.71748114], dtype=float32),
#   'probabilities': array([0.32794788, 0.6720521 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27870888], dtype=float32),
#   'logits': array([-0.95087504], dtype=float32),
#   'probabilities': array([0.7212911 , 0.27870888], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08958432], dtype=float32),
#   'logits': array([-2.3187208], dtype=float32),
#   'probabilities': array([0.91041565, 0.08958434], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15745503], dtype=float32),
#   'logits': array([-1.6772872], dtype=float32),
#   'probabilities': array([0.842545  , 0.15745501], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12046158], dtype=float32),
#   'logits': array([-1.988066], dtype=float32),
#   'probabilities': array([0.8795384 , 0.12046164], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9140401], dtype=float32),
#   'logits': array([2.3639936], dtype=float32),
#   'probabilities': array([0.0859599 , 0.91404015], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08203417], dtype=float32),
#   'logits': array([-2.4150238], dtype=float32),
#   'probabilities': array([0.91796577, 0.08203421], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72879255], dtype=float32),
#   'logits': array([0.98850536], dtype=float32),
#   'probabilities': array([0.2712074 , 0.72879255], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10821366], dtype=float32),
#   'logits': array([-2.109119], dtype=float32),
#   'probabilities': array([0.89178634, 0.10821366], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4005404], dtype=float32),
#   'logits': array([-0.40321398], dtype=float32),
#   'probabilities': array([0.5994596, 0.4005404], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28932744], dtype=float32),
#   'logits': array([-0.89865285], dtype=float32),
#   'probabilities': array([0.7106726, 0.2893274], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20138389], dtype=float32),
#   'logits': array([-1.3776674], dtype=float32),
#   'probabilities': array([0.7986161 , 0.20138387], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8328886], dtype=float32),
#   'logits': array([1.6062393], dtype=float32),
#   'probabilities': array([0.1671114 , 0.83288866], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10690281], dtype=float32),
#   'logits': array([-2.122775], dtype=float32),
#   'probabilities': array([0.89309716, 0.10690283], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3281543], dtype=float32),
#   'logits': array([-0.71654475], dtype=float32),
#   'probabilities': array([0.6718457, 0.3281543], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44442743], dtype=float32),
#   'logits': array([-0.2232124], dtype=float32),
#   'probabilities': array([0.55557257, 0.44442743], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44074786], dtype=float32),
#   'logits': array([-0.23812757], dtype=float32),
#   'probabilities': array([0.55925214, 0.44074783], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09096864], dtype=float32),
#   'logits': array([-2.3018646], dtype=float32),
#   'probabilities': array([0.9090314 , 0.09096865], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2245169], dtype=float32),
#   'logits': array([-1.2395353], dtype=float32),
#   'probabilities': array([0.77548313, 0.22451688], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05441096], dtype=float32),
#   'logits': array([-2.8552418], dtype=float32),
#   'probabilities': array([0.94558907, 0.054411  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08395228], dtype=float32),
#   'logits': array([-2.3898196], dtype=float32),
#   'probabilities': array([0.9160477 , 0.08395231], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11665592], dtype=float32),
#   'logits': array([-2.024486], dtype=float32),
#   'probabilities': array([0.88334405, 0.11665592], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0975284], dtype=float32),
#   'logits': array([-2.2249937], dtype=float32),
#   'probabilities': array([0.9024716 , 0.09752839], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16832736], dtype=float32),
#   'logits': array([-1.5975282], dtype=float32),
#   'probabilities': array([0.83167267, 0.16832738], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.96695757], dtype=float32),
#   'logits': array([3.376362], dtype=float32),
#   'probabilities': array([0.03304243, 0.9669575 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18244138], dtype=float32),
#   'logits': array([-1.4998938], dtype=float32),
#   'probabilities': array([0.81755865, 0.18244137], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08700678], dtype=float32),
#   'logits': array([-2.3507419], dtype=float32),
#   'probabilities': array([0.9129932 , 0.08700683], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28267992], dtype=float32),
#   'logits': array([-0.93120694], dtype=float32),
#   'probabilities': array([0.7173201 , 0.28267992], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55731964], dtype=float32),
#   'logits': array([0.23029102], dtype=float32),
#   'probabilities': array([0.44268033, 0.55731964], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19539058], dtype=float32),
#   'logits': array([-1.4153566], dtype=float32),
#   'probabilities': array([0.8046095 , 0.19539055], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8378145], dtype=float32),
#   'logits': array([1.6420562], dtype=float32),
#   'probabilities': array([0.16218546, 0.8378145 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17106748], dtype=float32),
#   'logits': array([-1.5780807], dtype=float32),
#   'probabilities': array([0.8289325 , 0.17106748], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6555068], dtype=float32),
#   'logits': array([0.6433344], dtype=float32),
#   'probabilities': array([0.34449318, 0.65550685], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4557334], dtype=float32),
#   'logits': array([-0.17753129], dtype=float32),
#   'probabilities': array([0.5442666 , 0.45573336], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09019959], dtype=float32),
#   'logits': array([-2.3112001], dtype=float32),
#   'probabilities': array([0.9098004 , 0.09019961], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11466101], dtype=float32),
#   'logits': array([-2.0439906], dtype=float32),
#   'probabilities': array([0.88533896, 0.114661  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65551555], dtype=float32),
#   'logits': array([0.64337313], dtype=float32),
#   'probabilities': array([0.34448448, 0.6555156 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9429971], dtype=float32),
#   'logits': array([2.8059602], dtype=float32),
#   'probabilities': array([0.05700295, 0.9429971 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48850366], dtype=float32),
#   'logits': array([-0.04599343], dtype=float32),
#   'probabilities': array([0.51149637, 0.4885037 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.03488055], dtype=float32),
#   'logits': array([-3.3203223], dtype=float32),
#   'probabilities': array([0.9651195 , 0.03488056], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11334386], dtype=float32),
#   'logits': array([-2.0570307], dtype=float32),
#   'probabilities': array([0.8866561 , 0.11334389], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12180167], dtype=float32),
#   'logits': array([-1.9754784], dtype=float32),
#   'probabilities': array([0.87819827, 0.12180166], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08260807], dtype=float32),
#   'logits': array([-2.4074273], dtype=float32),
#   'probabilities': array([0.91739196, 0.08260808], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10382089], dtype=float32),
#   'logits': array([-2.1554728], dtype=float32),
#   'probabilities': array([0.8961791 , 0.10382092], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12046158], dtype=float32),
#   'logits': array([-1.988066], dtype=float32),
#   'probabilities': array([0.8795384 , 0.12046164], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72634953], dtype=float32),
#   'logits': array([0.9761796], dtype=float32),
#   'probabilities': array([0.2736505 , 0.72634953], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9763674], dtype=float32),
#   'logits': array([3.721212], dtype=float32),
#   'probabilities': array([0.0236326, 0.9763674], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66407585], dtype=float32),
#   'logits': array([0.68151104], dtype=float32),
#   'probabilities': array([0.33592415, 0.6640759 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41210413], dtype=float32),
#   'logits': array([-0.35527378], dtype=float32),
#   'probabilities': array([0.5878958 , 0.41210413], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15791667], dtype=float32),
#   'logits': array([-1.6738116], dtype=float32),
#   'probabilities': array([0.8420834 , 0.15791668], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.96207637], dtype=float32),
#   'logits': array([3.233519], dtype=float32),
#   'probabilities': array([0.03792364, 0.9620763 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08224991], dtype=float32),
#   'logits': array([-2.4121625], dtype=float32),
#   'probabilities': array([0.91775006, 0.08224993], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59184384], dtype=float32),
#   'logits': array([0.37159288], dtype=float32),
#   'probabilities': array([0.4081562, 0.5918438], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6482155], dtype=float32),
#   'logits': array([0.6112044], dtype=float32),
#   'probabilities': array([0.3517845, 0.6482155], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08522642], dtype=float32),
#   'logits': array([-2.373365], dtype=float32),
#   'probabilities': array([0.9147736 , 0.08522644], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8222232], dtype=float32),
#   'logits': array([1.5314828], dtype=float32),
#   'probabilities': array([0.17777684, 0.8222232 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8599119], dtype=float32),
#   'logits': array([1.8145583], dtype=float32),
#   'probabilities': array([0.14008811, 0.85991186], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9732629], dtype=float32),
#   'logits': array([3.594604], dtype=float32),
#   'probabilities': array([0.02673705, 0.97326297], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1829055], dtype=float32),
#   'logits': array([-1.4967853], dtype=float32),
#   'probabilities': array([0.81709456, 0.18290548], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09241724], dtype=float32),
#   'logits': array([-2.284471], dtype=float32),
#   'probabilities': array([0.90758276, 0.09241726], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.979491], dtype=float32),
#   'logits': array([3.8661654], dtype=float32),
#   'probabilities': array([0.02050908, 0.97949094], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51315606], dtype=float32),
#   'logits': array([0.05263628], dtype=float32),
#   'probabilities': array([0.486844  , 0.51315606], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.85881436], dtype=float32),
#   'logits': array([1.8054773], dtype=float32),
#   'probabilities': array([0.14118563, 0.8588144 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20900181], dtype=float32),
#   'logits': array([-1.3309526], dtype=float32),
#   'probabilities': array([0.79099816, 0.20900182], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05719718], dtype=float32),
#   'logits': array([-2.8023527], dtype=float32),
#   'probabilities': array([0.94280285, 0.05719718], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10146475], dtype=float32),
#   'logits': array([-2.181054], dtype=float32),
#   'probabilities': array([0.8985352 , 0.10146479], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29045033], dtype=float32),
#   'logits': array([-0.8931979], dtype=float32),
#   'probabilities': array([0.70954967, 0.29045033], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08171916], dtype=float32),
#   'logits': array([-2.4192147], dtype=float32),
#   'probabilities': array([0.9182808 , 0.08171916], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74553216], dtype=float32),
#   'logits': array([1.0749238], dtype=float32),
#   'probabilities': array([0.25446784, 0.7455321 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5999704], dtype=float32),
#   'logits': array([0.40534174], dtype=float32),
#   'probabilities': array([0.4000296 , 0.59997034], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5737819], dtype=float32),
#   'logits': array([0.2972982], dtype=float32),
#   'probabilities': array([0.4262181, 0.5737819], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6766062], dtype=float32),
#   'logits': array([0.73821855], dtype=float32),
#   'probabilities': array([0.32339382, 0.6766062 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17125529], dtype=float32),
#   'logits': array([-1.5767568], dtype=float32),
#   'probabilities': array([0.8287447 , 0.17125528], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8259549], dtype=float32),
#   'logits': array([1.5572258], dtype=float32),
#   'probabilities': array([0.17404509, 0.8259549 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8706267], dtype=float32),
#   'logits': array([1.9065111], dtype=float32),
#   'probabilities': array([0.12937333, 0.8706267 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7510607], dtype=float32),
#   'logits': array([1.1042776], dtype=float32),
#   'probabilities': array([0.24893925, 0.7510607 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06135324], dtype=float32),
#   'logits': array([-2.7277908], dtype=float32),
#   'probabilities': array([0.93864673, 0.06135326], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7962148], dtype=float32),
#   'logits': array([1.3628025], dtype=float32),
#   'probabilities': array([0.20378521, 0.7962148 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68644494], dtype=float32),
#   'logits': array([0.7835511], dtype=float32),
#   'probabilities': array([0.31355503, 0.68644494], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6922603], dtype=float32),
#   'logits': array([0.8107079], dtype=float32),
#   'probabilities': array([0.30773965, 0.6922603 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04310575], dtype=float32),
#   'logits': array([-3.1000366], dtype=float32),
#   'probabilities': array([0.9568943 , 0.04310574], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.91403544], dtype=float32),
#   'logits': array([2.3639336], dtype=float32),
#   'probabilities': array([0.08596461, 0.9140354 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6844724], dtype=float32),
#   'logits': array([0.77440214], dtype=float32),
#   'probabilities': array([0.31552762, 0.6844724 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08444762], dtype=float32),
#   'logits': array([-2.3833957], dtype=float32),
#   'probabilities': array([0.9155523 , 0.08444765], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6780104], dtype=float32),
#   'logits': array([0.74464345], dtype=float32),
#   'probabilities': array([0.32198957, 0.6780104 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08673847], dtype=float32),
#   'logits': array([-2.354125], dtype=float32),
#   'probabilities': array([0.9132616 , 0.08673846], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8072189], dtype=float32),
#   'logits': array([1.4320399], dtype=float32),
#   'probabilities': array([0.19278106, 0.80721897], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57670194], dtype=float32),
#   'logits': array([0.30924904], dtype=float32),
#   'probabilities': array([0.42329803, 0.57670194], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09496695], dtype=float32),
#   'logits': array([-2.2544427], dtype=float32),
#   'probabilities': array([0.905033  , 0.09496693], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5663463], dtype=float32),
#   'logits': array([0.26695955], dtype=float32),
#   'probabilities': array([0.43365368, 0.56634635], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8623949], dtype=float32),
#   'logits': array([1.8353255], dtype=float32),
#   'probabilities': array([0.13760509, 0.8623949 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09210443], dtype=float32),
#   'logits': array([-2.2882056], dtype=float32),
#   'probabilities': array([0.90789557, 0.09210449], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.087071], dtype=float32),
#   'logits': array([-2.349934], dtype=float32),
#   'probabilities': array([0.912929  , 0.08707101], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65374744], dtype=float32),
#   'logits': array([0.6355529], dtype=float32),
#   'probabilities': array([0.3462525, 0.6537475], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10753563], dtype=float32),
#   'logits': array([-2.116164], dtype=float32),
#   'probabilities': array([0.89246434, 0.10753567], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.101257], dtype=float32),
#   'logits': array([-2.1833348], dtype=float32),
#   'probabilities': array([0.898743  , 0.10125704], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16790548], dtype=float32),
#   'logits': array([-1.6005447], dtype=float32),
#   'probabilities': array([0.83209455, 0.16790551], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06463543], dtype=float32),
#   'logits': array([-2.6721735], dtype=float32),
#   'probabilities': array([0.9353646 , 0.06463544], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67956513], dtype=float32),
#   'logits': array([0.7517742], dtype=float32),
#   'probabilities': array([0.3204348 , 0.67956513], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10363823], dtype=float32),
#   'logits': array([-2.1574376], dtype=float32),
#   'probabilities': array([0.89636177, 0.10363826], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04453507], dtype=float32),
#   'logits': array([-3.06592], dtype=float32),
#   'probabilities': array([0.9554649 , 0.04453512], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08203417], dtype=float32),
#   'logits': array([-2.4150238], dtype=float32),
#   'probabilities': array([0.91796577, 0.08203421], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10656565], dtype=float32),
#   'logits': array([-2.1263115], dtype=float32),
#   'probabilities': array([0.89343435, 0.10656566], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14240178], dtype=float32),
#   'logits': array([-1.7954831], dtype=float32),
#   'probabilities': array([0.8575982 , 0.14240178], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14400822], dtype=float32),
#   'logits': array([-1.7823904], dtype=float32),
#   'probabilities': array([0.8559918 , 0.14400823], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9352343], dtype=float32),
#   'logits': array([2.6700208], dtype=float32),
#   'probabilities': array([0.06476571, 0.93523425], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09005207], dtype=float32),
#   'logits': array([-2.3129995], dtype=float32),
#   'probabilities': array([0.90994793, 0.09005206], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09787282], dtype=float32),
#   'logits': array([-2.2210865], dtype=float32),
#   'probabilities': array([0.90212715, 0.09787283], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68574], dtype=float32),
#   'logits': array([0.78027785], dtype=float32),
#   'probabilities': array([0.31426, 0.68574], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.96308726], dtype=float32),
#   'logits': array([3.2615876], dtype=float32),
#   'probabilities': array([0.03691273, 0.9630873 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
# ...
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4583409], dtype=float32),
#   'logits': array([-0.16702352], dtype=float32),
#   'probabilities': array([0.54165906, 0.45834088], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07956851], dtype=float32),
#   'logits': array([-2.4482234], dtype=float32),
#   'probabilities': array([0.92043144, 0.07956857], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15042827], dtype=float32),
#   'logits': array([-1.7312458], dtype=float32),
#   'probabilities': array([0.8495717, 0.1504283], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7857586], dtype=float32),
#   'logits': array([1.2995465], dtype=float32),
#   'probabilities': array([0.21424136, 0.7857586 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5612402], dtype=float32),
#   'logits': array([0.24619676], dtype=float32),
#   'probabilities': array([0.43875983, 0.5612402 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09851819], dtype=float32),
#   'logits': array([-2.2137985], dtype=float32),
#   'probabilities': array([0.9014818, 0.0985182], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38440445], dtype=float32),
#   'logits': array([-0.470895], dtype=float32),
#   'probabilities': array([0.6155956 , 0.38440442], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2288442], dtype=float32),
#   'logits': array([-1.2148489], dtype=float32),
#   'probabilities': array([0.7711558 , 0.22884423], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.93751615], dtype=float32),
#   'logits': array([2.7083256], dtype=float32),
#   'probabilities': array([0.06248387, 0.9375162 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9281808], dtype=float32),
#   'logits': array([2.5590749], dtype=float32),
#   'probabilities': array([0.07181919, 0.9281809 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12337652], dtype=float32),
#   'logits': array([-1.9608369], dtype=float32),
#   'probabilities': array([0.87662345, 0.1233765 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66808766], dtype=float32),
#   'logits': array([0.6995486], dtype=float32),
#   'probabilities': array([0.33191234, 0.6680877 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09866399], dtype=float32),
#   'logits': array([-2.2121582], dtype=float32),
#   'probabilities': array([0.901336  , 0.09866398], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13939965], dtype=float32),
#   'logits': array([-1.8202851], dtype=float32),
#   'probabilities': array([0.86060035, 0.13939968], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6442677], dtype=float32),
#   'logits': array([0.5939357], dtype=float32),
#   'probabilities': array([0.35573232, 0.6442677 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1075294], dtype=float32),
#   'logits': array([-2.1162295], dtype=float32),
#   'probabilities': array([0.8924706 , 0.10752937], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.95190823], dtype=float32),
#   'logits': array([2.9853573], dtype=float32),
#   'probabilities': array([0.04809178, 0.9519082 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8270674], dtype=float32),
#   'logits': array([1.5649837], dtype=float32),
#   'probabilities': array([0.17293267, 0.8270673 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09479105], dtype=float32),
#   'logits': array([-2.2564907], dtype=float32),
#   'probabilities': array([0.9052089 , 0.09479105], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7046802], dtype=float32),
#   'logits': array([0.8696854], dtype=float32),
#   'probabilities': array([0.29531977, 0.70468026], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10437107], dtype=float32),
#   'logits': array([-2.1495733], dtype=float32),
#   'probabilities': array([0.89562887, 0.10437109], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2753855], dtype=float32),
#   'logits': array([-0.9674679], dtype=float32),
#   'probabilities': array([0.7246145, 0.2753855], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0892342], dtype=float32),
#   'logits': array([-2.323021], dtype=float32),
#   'probabilities': array([0.91076577, 0.08923424], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70498455], dtype=float32),
#   'logits': array([0.8711481], dtype=float32),
#   'probabilities': array([0.29501545, 0.70498455], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5491302], dtype=float32),
#   'logits': array([0.19715692], dtype=float32),
#   'probabilities': array([0.45086977, 0.54913014], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0548631], dtype=float32),
#   'logits': array([-2.8464887], dtype=float32),
#   'probabilities': array([0.9451369 , 0.05486311], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20425326], dtype=float32),
#   'logits': array([-1.3599204], dtype=float32),
#   'probabilities': array([0.79574674, 0.20425323], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.85060704], dtype=float32),
#   'logits': array([1.7393696], dtype=float32),
#   'probabilities': array([0.14939302, 0.850607  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39248154], dtype=float32),
#   'logits': array([-0.43689317], dtype=float32),
#   'probabilities': array([0.6075185, 0.3924815], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86907053], dtype=float32),
#   'logits': array([1.8927653], dtype=float32),
#   'probabilities': array([0.13092948, 0.8690705 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38844895], dtype=float32),
#   'logits': array([-0.45383668], dtype=float32),
#   'probabilities': array([0.61155105, 0.38844895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09741265], dtype=float32),
#   'logits': array([-2.2263088], dtype=float32),
#   'probabilities': array([0.90258723, 0.09741269], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11004999], dtype=float32),
#   'logits': array([-2.0902305], dtype=float32),
#   'probabilities': array([0.88995, 0.11005], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12039101], dtype=float32),
#   'logits': array([-1.9887323], dtype=float32),
#   'probabilities': array([0.8796089 , 0.12039103], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.02086824], dtype=float32),
#   'logits': array([-3.8484364], dtype=float32),
#   'probabilities': array([0.9791317 , 0.02086827], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8700496], dtype=float32),
#   'logits': array([1.901397], dtype=float32),
#   'probabilities': array([0.12995045, 0.87004954], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7132708], dtype=float32),
#   'logits': array([0.91132295], dtype=float32),
#   'probabilities': array([0.2867292, 0.7132708], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1394023], dtype=float32),
#   'logits': array([-1.8202631], dtype=float32),
#   'probabilities': array([0.86059767, 0.1394023 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21195427], dtype=float32),
#   'logits': array([-1.3131857], dtype=float32),
#   'probabilities': array([0.7880457 , 0.21195422], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8867363], dtype=float32),
#   'logits': array([2.0578282], dtype=float32),
#   'probabilities': array([0.11326378, 0.8867362 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38294587], dtype=float32),
#   'logits': array([-0.47706318], dtype=float32),
#   'probabilities': array([0.61705416, 0.38294587], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08767673], dtype=float32),
#   'logits': array([-2.3423376], dtype=float32),
#   'probabilities': array([0.91232324, 0.08767675], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8614464], dtype=float32),
#   'logits': array([1.8273555], dtype=float32),
#   'probabilities': array([0.13855362, 0.8614464 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81439745], dtype=float32),
#   'logits': array([1.4788408], dtype=float32),
#   'probabilities': array([0.18560258, 0.81439745], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07491958], dtype=float32),
#   'logits': array([-2.513466], dtype=float32),
#   'probabilities': array([0.9250804 , 0.07491954], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4872166], dtype=float32),
#   'logits': array([-0.05114482], dtype=float32),
#   'probabilities': array([0.5127834, 0.4872166], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18244138], dtype=float32),
#   'logits': array([-1.4998938], dtype=float32),
#   'probabilities': array([0.81755865, 0.18244137], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42059484], dtype=float32),
#   'logits': array([-0.320332], dtype=float32),
#   'probabilities': array([0.5794051, 0.4205948], dtype=float32)}]

# %%
result[0]
# Out:
# {'all_class_ids': array([0, 1], dtype=int32),
#  'all_classes': array([b'0', b'1'], dtype=object),
#  'class_ids': array([0]),
#  'classes': array([b'0'], dtype=object),
#  'logistic': array([0.07058433], dtype=float32),
#  'logits': array([-2.5777478], dtype=float32),
#  'probabilities': array([0.92941564, 0.07058433], dtype=float32)}

# %%
dfeval.loc[5]
y_eval.loc[5]
result[0]['probabilities'][0]
# Out:
# 0.92941564

# %%
dfeval.loc[0]
# Out:
# sex                          male
# age                          35.0
# n_siblings_spouses              0
# parch                           0
# fare                         8.05
# class                       Third
# deck                      unknown
# embark_town           Southampton
# alone                           y
# Name: 0, dtype: object
